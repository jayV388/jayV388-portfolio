# %% [markdown]
# # Airbnb Data Profiling
#
# The raw Airbnb dataset is examined in this notebooks prior to data processing and cleaning.
#
# '01_profiling' reads the raw Airbnb data, but it does not clean or change anything. Its job is to answer: "What does this raw dataset looks like before I start cleaning it?"

# %%
import pandas as pd 
import numpy as np 
from pathlib import Path

# %%
# set project paths

project_path = Path.cwd().parent

raw_data_path = (
    project_path
    /'data'
    /'raw'
    /'Airbnb_Open_Data.csv'
)

print(raw_data_path)
# Out:
# c:\Users\jayvy\OneDrive\Documents\jayV388-portfolio\Projects\airbnb_analysis\data\raw\Airbnb_Open_Data.csv

# %%
# load the data

df_raw = pd.read_csv(raw_data_path)

print('Dataset loaded successfully!')
print(f'Dataset shape: {df_raw.shape}')
# Out:
# Dataset loaded successfully!
# Dataset shape: (102599, 26)
# C:\Users\jayvy\AppData\Local\Temp\ipykernel_11116\304572302.py:3: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_raw = pd.read_csv(raw_data_path)
